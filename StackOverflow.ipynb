# %%
import pandas as pd

# %%
train = pd.read_csv('train.csv')
train.head(10)
# Out:
#          Id                                              Title  \
# 0  34552656             Java: Repeat Task Every Random Seconds
# 1  34553034                  Why are Java Optionals immutable?
# 2  34553174  Text Overlay Image with Darkened Opacity React...
# 3  34553318         Why ternary operator in swift is so picky?
# 4  34553755                 hide/show fab with scale animation
# 5  34554026  Accessing pointer member of the structure usin...
# 6  34554206  How To Disable 2nd Saturday 4th Saturday ,Sund...
# 7  34554671                   Resizing containers in bootstrap
# 8  34554871  Changing Theme in Windows 10 UWP App Programma...
# 9  34554982                       TextBox Value Disappears VB6
#
#                                                 Body  \
# 0  <p>I'm already familiar with repeating tasks e...
# 1  <p>I'd like to understand why Java 8 Optionals...
# 2  <p>I am attempting to overlay a title over an ...
# 3  <p>The question is very simple, but I just cou...
# 4  <p>I'm using custom floatingactionmenu. I need...
# 5  <p>I have defined integer pointer inside the s...
# 6    i want to Disable 2nd Saturday 4th saturday,...
# 7  I am new to bootstrap and i would like to find...
# 8  <p>I was able to change theme using <code>this...
# 9  I my case I am having two form Form 1 and Form...
#
#                                                 Tags         CreationDate  \
# 0                                     <java><repeat>  2016-01-01 00:21:59
# 1                                   <java><optional>  2016-01-01 02:03:20
# 2  <javascript><overlay><react-native><opa...  2016-01-01 02:48:24
# 3  <swift><operators><whitespace><ternary-operato...  2016-01-01 03:30:17
# 4  <android><material-design><floating-action-but...  2016-01-01 05:21:48
# 5                     <c><pointers><data-structures>  2016-01-01 06:21:17
# 6                    <javascript><jquery><jquery-ui>  2016-01-01 06:55:18
# 7             <jquery><html><css><twitter-bootstrap>  2016-01-01 08:32:05
# 8  <c#><windows-10><windows-10-mobile><windows-10...  2016-01-01 09:05:45
# 9                                              <vb6>  2016-01-01 09:27:44
#
#           Y
# 0  LQ_CLOSE
# 1        HQ
# 2        HQ
# 3        HQ
# 4        HQ
# 5  LQ_CLOSE
# 6   LQ_EDIT
# 7   LQ_EDIT
# 8        HQ
# 9   LQ_EDIT

# %%
test = pd.read_csv('valid.csv')
test.head(10)
# Out:
#          Id                                              Title  \
# 0  34552974  How to get all the child records from differen...
# 1  34554721  Retrieve all except some data of the another t...
# 2  34555135                                  Pandas: read_html
# 3  34555448                           Reader Always gimme NULL
# 4  34555752    php rearrange array elements based on condition
# 5  34557209   How do I make a constructor for a derived class?
# 6  34557363  how can i create a dynamic tow dimensional arr...
# 7  34557587                Re-exporting ES6 modules in TS 1.7?
# 8  34558264                              Fetch API with Cookie
# 9  34559136                Print list content in a given order
#
#                                                 Body  \
# 0  I am having 4 different tables like \r\nselect...
# 1  I have two table m_master and tbl_appointment\...
# 2  <p>I'm trying to extract US states from wiki U...
# 3  I'm so new to C#, I wanna make an application ...
# 4  basically i have this array:\r\n\r\n    array(...
# 5  <p>I am trying to make a constructor for a der...
# 6   I am using c++ in my lesson and for solving a...
# 7  <p>I'm getting a bit lost in TS re-exports. Sa...
# 8  <p>I am trying out the new Fetch API but is ha...
# 9  <pre><code>lt = ['7,777.7', '777.7', '77,777.7...
#
#                                                 Tags         CreationDate  \
# 0                                  <sql><sql-server>  2016-01-01 01:44:52
# 1             <php><mysql><sql><codeigniter><mysqli>  2016-01-01 08:43:50
# 2                                   <python><pandas>  2016-01-01 09:55:22
# 3                               <sql-server><c#-4.0>  2016-01-01 10:43:45
# 4                                              <php>  2016-01-01 11:34:09
# 5     <c++><inheritance><constructor><derived-class>  2016-01-01 14:58:52
# 6                                              <c++>  2016-01-01 15:21:17
# 7  <typescript><ecmascript-6><es6-module-loader><...  2016-01-01 15:50:30
# 8                               <cookies><fetch-api>  2016-01-01 17:21:19
# 9               <python><list><python-2.7><for-loop>  2016-01-01 19:08:12
#
#           Y
# 0   LQ_EDIT
# 1   LQ_EDIT
# 2        HQ
# 3   LQ_EDIT
# 4   LQ_EDIT
# 5  LQ_CLOSE
# 6   LQ_EDIT
# 7        HQ
# 8        HQ
# 9  LQ_CLOSE

# %%
#Now lets use this 2 datasets as train and test

# %%
X_train, y_train = train.drop(['Y'], axis = 1), train["Y"]
X_test, y_test = test.drop(['Y'], axis = 1), test["Y"]

# %%
train.head(10)
# Out:
#          Id                                              Title  \
# 0  34552656             Java: Repeat Task Every Random Seconds
# 1  34553034                  Why are Java Optionals immutable?
# 2  34553174  Text Overlay Image with Darkened Opacity React...
# 3  34553318         Why ternary operator in swift is so picky?
# 4  34553755                 hide/show fab with scale animation
# 5  34554026  Accessing pointer member of the structure usin...
# 6  34554206  How To Disable 2nd Saturday 4th Saturday ,Sund...
# 7  34554671                   Resizing containers in bootstrap
# 8  34554871  Changing Theme in Windows 10 UWP App Programma...
# 9  34554982                       TextBox Value Disappears VB6
#
#                                                 Body  \
# 0  <p>I'm already familiar with repeating tasks e...
# 1  <p>I'd like to understand why Java 8 Optionals...
# 2  <p>I am attempting to overlay a title over an ...
# 3  <p>The question is very simple, but I just cou...
# 4  <p>I'm using custom floatingactionmenu. I need...
# 5  <p>I have defined integer pointer inside the s...
# 6    i want to Disable 2nd Saturday 4th saturday,...
# 7  I am new to bootstrap and i would like to find...
# 8  <p>I was able to change theme using <code>this...
# 9  I my case I am having two form Form 1 and Form...
#
#                                                 Tags         CreationDate  \
# 0                                     <java><repeat>  2016-01-01 00:21:59
# 1                                   <java><optional>  2016-01-01 02:03:20
# 2  <javascript><overlay><react-native><opa...  2016-01-01 02:48:24
# 3  <swift><operators><whitespace><ternary-operato...  2016-01-01 03:30:17
# 4  <android><material-design><floating-action-but...  2016-01-01 05:21:48
# 5                     <c><pointers><data-structures>  2016-01-01 06:21:17
# 6                    <javascript><jquery><jquery-ui>  2016-01-01 06:55:18
# 7             <jquery><html><css><twitter-bootstrap>  2016-01-01 08:32:05
# 8  <c#><windows-10><windows-10-mobile><windows-10...  2016-01-01 09:05:45
# 9                                              <vb6>  2016-01-01 09:27:44
#
#           Y
# 0  LQ_CLOSE
# 1        HQ
# 2        HQ
# 3        HQ
# 4        HQ
# 5  LQ_CLOSE
# 6   LQ_EDIT
# 7   LQ_EDIT
# 8        HQ
# 9   LQ_EDIT

# %%
train.hist()
# Out:
# array([[<AxesSubplot:title={'center':'Id'}>]], dtype=object)

# %%
#Using Naive Bayes
from sklearn.naive_bayes import GaussianNB

# %%
naive = GaussianNB()
naive.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [37], in <cell line: 2>()
#       1 naive = GaussianNB()
# ----> 2 naive.fit(X_train, y_train)
#
# File C:\Anaconda\lib\site-packages\sklearn\naive_bayes.py:245, in GaussianNB.fit(self, X, y, sample_weight)
#     222 """Fit Gaussian Naive Bayes according to X, y.
#     223
#     224 Parameters
#    (...)
#     242     Returns the instance itself.
#     243 """
#     244 y = self._validate_data(y=y)
# --> 245 return self._partial_fit(
#     246     X, y, np.unique(y), _refit=True, sample_weight=sample_weight
#     247 )
#
# File C:\Anaconda\lib\site-packages\sklearn\naive_bayes.py:402, in GaussianNB._partial_fit(self, X, y, classes, _refit, sample_weight)
#     399     self.classes_ = None
#     401 first_call = _check_partial_fit_first_call(self, classes)
# --> 402 X, y = self._validate_data(X, y, reset=first_call)
#     403 if sample_weight is not None:
#     404     sample_weight = _check_sample_weight(sample_weight, X)
#
# File C:\Anaconda\lib\site-packages\sklearn\base.py:581, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     579         y = check_array(y, **check_y_params)
#     580     else:
# --> 581         X, y = check_X_y(X, y, **check_params)
#     582     out = X, y
#     584 if not no_val_X and check_params.get("ensure_2d", True):
#
# File C:\Anaconda\lib\site-packages\sklearn\utils\validation.py:964, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     961 if y is None:
#     962     raise ValueError("y cannot be None")
# --> 964 X = check_array(
#     965     X,
#     966     accept_sparse=accept_sparse,
#     967     accept_large_sparse=accept_large_sparse,
#     968     dtype=dtype,
#     969     order=order,
#     970     copy=copy,
#     971     force_all_finite=force_all_finite,
#     972     ensure_2d=ensure_2d,
#     973     allow_nd=allow_nd,
#     974     ensure_min_samples=ensure_min_samples,
#     975     ensure_min_features=ensure_min_features,
#     976     estimator=estimator,
#     977 )
#     979 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric)
#     981 check_consistent_length(X, y)
#
# File C:\Anaconda\lib\site-packages\sklearn\utils\validation.py:746, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     744         array = array.astype(dtype, casting="unsafe", copy=False)
#     745     else:
# --> 746         array = np.asarray(array, order=order, dtype=dtype)
#     747 except ComplexWarning as complex_warning:
#     748     raise ValueError(
#     749         "Complex data not supported\n{}\n".format(array)
#     750     ) from complex_warning
#
# File C:\Anaconda\lib\site-packages\pandas\core\generic.py:2064, in NDFrame.__array__(self, dtype)
#    2063 def __array__(self, dtype: npt.DTypeLike | None = None) -> np.ndarray:
# -> 2064     return np.asarray(self._values, dtype=dtype)
#
# ValueError: could not convert string to float: 'Java: Repeat Task Every Random Seconds'

# %%
pred = naive.predict(X_test)
